# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('../logs/1_rectified_flow/eval/ckpt_3/samples_4.npz')
print((data))

# Assuming the images are stored in an array called 'samples'
images = data['samples']

# Display the first image
plt.imshow(images[0])
plt.show()
