# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('../logs/1_rectified_flow/eval/ckpt_2/samples_0.npz')

# Assuming the images are stored in an array called 'samples'
images = data['samples']

# Display the first image
plt.imshow(images[0])
plt.show()

# %%
import torch

# Check if CUDA (GPU) is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU is available. Using device: {device}")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("GPU not available. Using CPU.")

    import torch
print(torch.version.cuda)  # Should output a valid CUDA version if CUDA is enabled
print(torch.cuda.is_available())  # Should return True if CUDA is available
print(torch.__version__)
# Out:
# GPU is available. Using device: cuda
# Number of GPUs available: 1
# Current GPU: NVIDIA RTX A4000
# 11.3
# True
# 1.11.0+cu113
